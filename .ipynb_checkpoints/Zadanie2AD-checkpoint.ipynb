# %% [markdown]
# ## Import section

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# ### Dealing with missing data example

# %%
missing_values = ['na', 'n/a', '--']
data = pd.read_csv("./data/property.csv", na_values=missing_values)
data = data.drop(columns='PID')
print(data)
for i, row in enumerate(data['OWN_OCCUPIED']):
    try:
        int(row)
        data.loc[i, 'OWN_OCCUPIED']=np.nan
    except ValueError:
        pass

for i, row in enumerate(data['NUM_BATH']):
    try:
        float(row)
    except ValueError:
        data.loc[i, 'NUM_BATH'] = np.nan
# Out:
#    ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2     NaN   LEXINGTON            N           NaN        1   850.0
# 3   201.0    BERKELEY           12           1.0      NaN   700.0
# 4   203.0    BERKELEY            Y           3.0        2  1600.0
# 5   207.0    BERKELEY            Y           NaN        1   800.0
# 6     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7   213.0     TREMONT            Y           1.0        1     NaN
# 8   215.0     TREMONT            Y           NaN        2  1800.0

# %%
print(data)

print(data.isnull().sum() * 100 / len(data))
# Out:
#    ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2     NaN   LEXINGTON            N           NaN        1   850.0
# 3   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4   203.0    BERKELEY            Y           3.0        2  1600.0
# 5   207.0    BERKELEY            Y           NaN        1   800.0
# 6     NaN  WASHINGTON          NaN           2.0      NaN   950.0
# 7   213.0     TREMONT            Y           1.0        1     NaN
# 8   215.0     TREMONT            Y           NaN        2  1800.0
# ST_NUM          22.222222
# ST_NAME          0.000000
# OWN_OCCUPIED    22.222222
# NUM_BEDROOMS    33.333333
# NUM_BATH        22.222222
# SQ_FT           22.222222
# dtype: float64

# %% [markdown]
# >https://scikit-learn.org/stable/modules/impute.html#impute
# >https://medium.com/better-programming/handling-missing-data-in-python-using-scikit-imputer-7607c8957740

# %% [markdown]
# # Data preparation and toolbox

# %%
# toolbox
def set_percentage_of_values_to_nan(df, percentage):
    return df.mask(np.random.random(df.shape) < percentage)
def show_nan_percentage(df):
    print(df.isnull().sum() * 100 / len(df))
def hist_of_selected_column(df, column_name):
    hs = df[column_name]
    plt.hist(hs)
    plt.xlabel(column_name)
    plt.show()
def plot_of_two_columns(df, f_c, s_c):
    plt.plot(f_c,s_c, 'b.', data=df)
    plt.xlabel(f_c)
    plt.ylabel(s_c)
    plt.show()

# %%
df = pd.read_csv("./data/Olympic-atheletes.csv", sep=";")
df = df.drop(columns = 'ID')
df = df.drop_duplicates(subset="Name")

df['Height'] = set_percentage_of_values_to_nan(df['Height'], 0.05)
df['Weight'] = set_percentage_of_values_to_nan(df['Weight'], 0.05)
man_df = df[df['Sex'] == 'M']
woman_df = df[df['Sex'] == 'F']
disciplines = df['Sport'].unique()
man_players_by_discipline = {}
woman_players_by_discipline = {}
for d in disciplines:
    man_players_by_discipline[d] = man_df[man_df['Sport'] == d]
    woman_players_by_discipline[d] = woman_df[woman_df['Sport'] == d]

model = LinearRegression()
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
print(df[['Team', 'Height', 'Weight']].head(20))
t = df[['Team', 'Height', 'Weight']].head(20)
t = t[t['Height'].notna()]
print(t)
# Out:
#              Team  Height  Weight
# 0         Romania   170.0     NaN
# 1           Spain   167.0    64.0
# 7           Spain   170.0    65.0
# 8           Italy   198.0    90.0
# 9      Azerbaijan   165.0    49.0
# 10         France   182.0    86.0
# 11        Algeria   175.0    75.0
# 12        Bahrain   175.0    66.0
# 13    Netherlands   178.0    72.0
# 14           Iraq   180.0   104.0
# 15        Ireland   167.0     NaN
# 17  United States   163.0    52.0
# 18          Egypt   203.0    97.0
# 19          Egypt   172.0    61.0
# 20          Egypt   197.0    87.0
# 21          Egypt   170.0    60.0
# 23          Egypt   165.0    57.0
# 24          Egypt   188.0    89.0
# 25          Egypt   176.0    60.0
# 26          Egypt   175.0    81.0
#              Team  Height  Weight
# 0         Romania   170.0     NaN
# 1           Spain   167.0    64.0
# 7           Spain   170.0    65.0
# 8           Italy   198.0    90.0
# 9      Azerbaijan   165.0    49.0
# ...

# %% [markdown]
# ## Handle NaN values

# %%
d_list = disciplines.tolist()
for d in d_list:
    if len(man_players_by_discipline[d]) < 500:
        d_list.remove(d)

disciplines = np.array(d_list)
print(disciplines)
# Out:
# ['Athletics' 'Equestrianism' 'Judo' 'Swimming' 'Modern Pentathlon'
#  'Hockey']

# %% [markdown]
# ## Regression for different sports

# %%
i = 1
f, axarr = plt.subplots(5,3, sharex=True, sharey=True,figsize=(12,12))
f.suptitle('Zależność wzrostu i wagi męskich zawodników według dyscypliny')
for i in range(0,5):
    for j in range(0,3):
        regression_set = man_players_by_discipline[disciplines[j+i*3]][['Height', 'Weight']].dropna()
        xs = regression_set['Height'].to_numpy().reshape((-1,1))
        ys = regression_set['Weight'].to_numpy().reshape((-1,1))
        x_train,x_test,y_train,y_test=train_test_split(xs,ys,test_size=0.4)
        model.fit(x_train,y_train)
        y_test = model.predict(x_test)
        print('coefficients:', model.coef_)
        axarr[i,j].set_title(disciplines[j+i*3])
        axarr[i,j].scatter(x_train, y_train, color="red")
        axarr[i,j].plot(x_test, y_test, color="blue", linewidth=1)
# Out:
# coefficients: [[1.3284194]]
# coefficients: [[0.55934439]]
# coefficients: [[1.84618128]]
# coefficients: [[0.81098989]]
# coefficients: [[0.72953635]]
# coefficients: [[0.98083645]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-9f7b260a3881> in <module>
#       4 for i in range(0,5):
#       5     for j in range(0,3):
# ----> 6         regression_set = man_players_by_discipline[disciplines[j+i*3]][['Height', 'Weight']].dropna()
#       7         xs = regression_set['Height'].to_numpy().reshape((-1,1))
#       8         ys = regression_set['Weight'].to_numpy().reshape((-1,1))
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
f, axarr = plt.subplots(15,2, sharex=True, sharey=True,figsize=(12,20))
f.suptitle('Zależność wzrostu i wagi męskich zawodników według dyscypliny')
for i in range(0,15):
    regression_set = man_players_by_discipline[disciplines[i]][['Height', 'Weight']].dropna()
    xs = regression_set['Height'].to_numpy().reshape((-1,1))
    ys = regression_set['Weight'].to_numpy().reshape((-1,1))
    x_train,x_test,y_train,y_test=train_test_split(xs,ys,test_size=0.4)
    model.fit(x_train,y_train)
    y_test = model.predict(x_test)
    print('Male players: ' + str(disciplines[i]))
    print(regression_set.describe())
    drop_nan_coef = model.coef_
    print('drop NaN: coefficients:', drop_nan_coef)
    axarr[i,0].set_title(disciplines[i])
    axarr[i,0].scatter(x_train, y_train, color="red")
    axarr[i,0].plot(x_test, y_test, color="blue", linewidth=1)
    mean_regression_set = man_players_by_discipline[disciplines[i]][['Height', 'Weight']]
    xs_mean = mean_regression_set['Height'].to_numpy().reshape((-1,1))
    ys_mean = mean_regression_set['Weight'].to_numpy().reshape((-1,1))
    imputer = imputer.fit(xs_mean)
    xs_mean = imputer.transform(xs_mean)
    imputer = imputer.fit(ys_mean)
    ys_mean = imputer.transform(ys_mean)
    x_train,x_test,y_train,y_test=train_test_split(xs,ys,test_size=0.4)
    model.fit(x_train,y_train)
    y_test = model.predict(x_test)
    result_df = pd.DataFrame({
        'Height': xs_mean[:,0],
        'Weight' : ys_mean[:,0]
    })
    print(result_df.describe())
    print('mean NaN: coefficients:', model.coef_)
    print('Coefficients difference: ' + str(abs((model.coef_[0,0] - drop_nan_coef[0,0]))) + "\n\n")
    axarr[i,1].set_title(disciplines[i])
    axarr[i,1].scatter(x_train, y_train, color="red")
    axarr[i,1].plot(x_test, y_test, color="blue", linewidth=1)
# Out:
# Male players: Weightlifting
#            Height      Weight
# count  135.000000  135.000000
# mean   170.866667   88.037037
# std     10.953634   27.800034
# min    148.000000   53.000000
# 25%    162.000000   68.000000
# 50%    170.000000   85.000000
# 75%    180.000000  103.500000
# max    197.000000  160.000000
# drop NaN: coefficients: [[2.36198206]]
#            Height      Weight
# count  152.000000  152.000000
# mean   170.780142   87.616438
# std     10.647944   26.580942
# min    148.000000   53.000000
# 25%    162.750000   69.000000
# 50%    170.780142   85.000000
# 75%    179.250000   95.500000
# max    197.000000  160.000000
# mean NaN: coefficients: [[2.18905349]]
# Coefficients difference: 0.1729285685861801
#
#
# Male players: Athletics
#             Height       Weight
# count  1002.000000  1002.000000
# mean    180.991018    74.722555
# std       9.136271    17.992475
# min     152.000000    47.000000
# 25%     175.000000    63.000000
# ...
